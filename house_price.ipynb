# %%
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Data Preparation, Cleaning and EDA

# %%
data = pd.read_csv("House_Price.csv")

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# 1      Lake        42     YES  0.046146
# 2      None        38     YES  0.045764
# 3      Lake        45     YES  0.047151
# 4      Lake        55     YES  0.039474

# %%
data.tail()
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 501   2.76   2.06      19.0       9.67      NO       9.348      12.1792
# 502   2.46   2.14      19.0       9.08     YES       6.612      13.1648
# 503   2.29   1.98      19.0       5.64      NO       5.478      12.1912
# 504   2.40   2.31      19.0       6.48     YES       7.940      15.1760
# 505   2.64   2.42      19.0       7.88     YES      10.280      10.1520
#
#           waterbody  rainfall bus_ter     parks
# 501  Lake and River        27     YES  0.056006
# 502  Lake and River        20     YES  0.059903
# 503            None        31     YES  0.057572
# 504            None        47     YES  0.060694
# 505            None        45     YES  0.060336

# %%
data.shape
# Out:
# (506, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
#  18  parks        506 non-null    float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 75.2+ KB

# %%
data.isna().sum()
# Out:
# price          0
# crime_rate     0
# resid_area     0
# air_qual       0
# room_num       0
# age            0
# dist1          0
# dist2          0
# dist3          0
# dist4          0
# teachers       0
# poor_prop      0
# airport        0
# n_hos_beds     8
# n_hot_rooms    0
# waterbody      0
# rainfall       0
# bus_ter        0
# parks          0
# dtype: int64

# %%
data.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# std      2.108532    2.108580    2.119797    2.099203    2.164946    7.141062
# min      1.130000    0.920000    1.150000    0.730000   18.000000    1.730000
# 25%      2.270000    1.940000    2.232500    1.940000   19.800000    6.950000
# 50%      3.385000    3.010000    3.375000    3.070000   20.950000   11.360000
# 75%      5.367500    4.992500    5.407500    4.985000   22.600000   16.955000
# max     12.320000   11.930000   12.320000   11.940000   27.400000   37.970000
#
#        n_hos_beds  n_hot_rooms    rainfall       parks
# count  498.000000   506.000000  506.000000  506.000000
# mean     7.899767    13.041605   39.181818    0.054454
# std      1.476683     5.238957   12.513697    0.010632
# min      5.268000    10.057600    3.000000    0.033292
# 25%      6.634500    11.189800   28.000000    0.046464
# 50%      7.999000    12.720000   39.000000    0.053507
# 75%      9.088000    14.170800   50.000000    0.061397
# max     10.876000   101.120000   60.000000    0.086711

# %%
sns.jointplot(x = "rainfall", y = "price", data = data)

# %%
sns.jointplot(x = "crime_rate", y = "price", data = data)

# %%
sns.scatterplot(x= "n_hot_rooms", y = "price", data = data)
# Out:
# <AxesSubplot:xlabel='n_hot_rooms', ylabel='price'>

# %%
sns.countplot(x= "airport", data = data)
# Out:
# <AxesSubplot:xlabel='airport', ylabel='count'>

# %%
sns.countplot(x="waterbody", data = data)
# Out:
# <AxesSubplot:xlabel='waterbody', ylabel='count'>

# %%
sns.countplot(x = "bus_ter", data = data)
# Out:
# <AxesSubplot:xlabel='bus_ter', ylabel='count'>

# %%
data["waterbody"].unique()
# Out:
# array(['River', 'Lake', 'None', 'Lake and River'], dtype=object)

# %% [markdown]
# ## Observation
#
# - 506 Entries
#
# - Categorical columns
#
#     - airport
#     - waterbody
#     - bus_ter
# - Missing Values
#     - n_hos_beds
#     - waterbody
# - Abnomalites:
#     - crime_rate
#     - age
#     - n_hot_rooms
#     - rainfall
# - Outlier:
#     - rainfall
#     - n_hot_room
#
# - bus_ter only has `yes` values

# %% [markdown]
# ## Missing Values Interpulation

# %%
data["n_hos_beds"].isna().sum()
# Out:
# 8

# %%
data["n_hos_beds"].mean()
# Out:
# 7.899767068273099

# %%
data["n_hos_beds"] = data["n_hos_beds"].fillna(data["n_hos_beds"].mean())

# %%
data["n_hos_beds"].isna().sum()
# Out:
# 0

# %%
data["waterbody"].isna().sum()
# Out:
# 0

# %%
data["waterbody"] = data["waterbody"].fillna("none")

# %%
sns.countplot(x ="waterbody", data = data)
# Out:
# <AxesSubplot:xlabel='waterbody', ylabel='count'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
#  18  parks        506 non-null    float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 75.2+ KB

# %%
df = pd.DataFrame([6,6,6,4,4,5,5,5,5,7,7,300])

# %%
df.describe()
# Out:
#                 0
# count   12.000000
# mean    30.000000
# std     85.033683
# min      4.000000
# 25%      5.000000
# 50%      5.500000
# 75%      6.250000
# max    300.000000

# %%
P99 = 7

# %%
df[df>7] = 21

# %%
df.describe()
# Out:
#                0
# count  12.000000
# mean    6.750000
# std     4.594958
# min     4.000000
# 25%     5.000000
# 50%     5.500000
# 75%     6.250000
# max    21.000000

# %%
np.percentile(data["rainfall"], 1)
# Out:
# 20.0

# %%
lower_value = np.percentile(data["rainfall"], 1)

# %%
data[data["rainfall"] < lower_value]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None         3     YES  0.044019

# %%
data["rainfall"][data["rainfall"] < lower_value] = 0.3 * lower_value
# Out:
# C:\Users\Chiedu\AppData\Local\Temp\ipykernel_13056\730997702.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["rainfall"][data["rainfall"] < lower_value] = 0.3 * lower_value

# %%
data.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# std      2.108532    2.108580    2.119797    2.099203    2.164946    7.141062
# min      1.130000    0.920000    1.150000    0.730000   18.000000    1.730000
# 25%      2.270000    1.940000    2.232500    1.940000   19.800000    6.950000
# 50%      3.385000    3.010000    3.375000    3.070000   20.950000   11.360000
# 75%      5.367500    4.992500    5.407500    4.985000   22.600000   16.955000
# max     12.320000   11.930000   12.320000   11.940000   27.400000   37.970000
#
#        n_hos_beds  n_hot_rooms    rainfall       parks
# count  506.000000   506.000000  506.000000  506.000000
# mean     7.899767    13.041605   39.187747    0.054454
# std      1.464939     5.238957   12.497221    0.010632
# min      5.268000    10.057600    6.000000    0.033292
# 25%      6.659000    11.189800   28.000000    0.046464
# 50%      7.963000    12.720000   39.000000    0.053507
# 75%      9.076000    14.170800   50.000000    0.061397
# max     10.876000   101.120000   60.000000    0.086711

# %%
np.percentile(data.n_hot_rooms, 99)
# Out:
# 15.39952

# %%
uv = np.percentile(data.n_hot_rooms, 99)

# %%
data[data["n_hot_rooms"] > uv]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# 423   2.34   1.87      19.8      23.29      NO       8.268        81.12
#
#     waterbody  rainfall bus_ter     parks
# 2        None        38     YES  0.045764
# 166     River        37     YES  0.052105
# 204     River        51     YES  0.044178
# 267      None        42     YES  0.063235
# 369     River        58     YES  0.067477
# 423      Lake        29     YES  0.063344

# %%
data["n_hot_rooms"][data["n_hot_rooms"] > 3*uv]  = 3*uv
# Out:
# C:\Users\Chiedu\AppData\Local\Temp\ipykernel_13056\2110423088.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["n_hot_rooms"][data["n_hot_rooms"] > 3*uv]  = 3*uv

# %%
data.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# std      2.108532    2.108580    2.119797    2.099203    2.164946    7.141062
# min      1.130000    0.920000    1.150000    0.730000   18.000000    1.730000
# 25%      2.270000    1.940000    2.232500    1.940000   19.800000    6.950000
# 50%      3.385000    3.010000    3.375000    3.070000   20.950000   11.360000
# 75%      5.367500    4.992500    5.407500    4.985000   22.600000   16.955000
# max     12.320000   11.930000   12.320000   11.940000   27.400000   37.970000
#
#        n_hos_beds  n_hot_rooms    rainfall       parks
# count  506.000000   506.000000  506.000000  506.000000
# mean     7.899767    12.864050   39.187747    0.054454
# std      1.464939     2.688778   12.497221    0.010632
# min      5.268000    10.057600    6.000000    0.033292
# 25%      6.659000    11.189800   28.000000    0.046464
# 50%      7.963000    12.720000   39.000000    0.053507
# 75%      9.076000    14.170800   50.000000    0.061397
# max     10.876000    46.198560   60.000000    0.086711

# %%
sns.scatterplot(x = data["rainfall"], y = data["price"])
# Out:
# <AxesSubplot:xlabel='rainfall', ylabel='price'>

# %%
data.bus_ter.unique()
# Out:
# array(['YES'], dtype=object)

# %%
data.drop("bus_ter", axis =1, inplace = True)

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480     11.19200
# 1   5.12   5.06      22.2       9.14      NO       7.332     12.17280
# 2   5.01   4.97      22.2       4.03      NO       7.394     46.19856
# 3   6.16   5.96      21.3       2.94     YES       9.268     11.26720
# 4   6.37   5.86      21.3       5.33      NO       8.824     11.28960
#
#   waterbody  rainfall     parks
# 0     River        23  0.049347
# 1      Lake        42  0.046146
# 2      None        38  0.045764
# 3      Lake        45  0.047151
# 4      Lake        55  0.039474

# %%
data.shape
# Out:
# (506, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  parks        506 non-null    float64
# dtypes: float64(15), int64(1), object(2)
# memory usage: 71.3+ KB

# %%
sns.scatterplot(x = data["crime_rate"], y = data["price"])
# Out:
# <AxesSubplot:xlabel='crime_rate', ylabel='price'>

# %%
data.crime_rate.describe()
# Out:
# count    506.000000
# mean       3.613524
# std        8.601545
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677083
# max       88.976200
# Name: crime_rate, dtype: float64

# %%
sns.displot(x = "crime_rate", data = data)

# %%
sns.distplot(x =data.price,  hist=True, kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
data["crime_rate"].describe()
# Out:
# count    506.000000
# mean       3.613524
# std        8.601545
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677083
# max       88.976200
# Name: crime_rate, dtype: float64

# %%
np.log(data["crime_rate"]).describe()
# Out:
# count    506.000000
# mean      -0.780436
# std        2.162050
# min       -5.064036
# 25%       -2.500488
# 50%       -1.360641
# 75%        1.302119
# max        4.488369
# Name: crime_rate, dtype: float64

# %%
np.sqrt(data["crime_rate"]).describe()
# Out:
# count    506.000000
# mean       1.229439
# std        1.451263
# min        0.079498
# 25%        0.286435
# 50%        0.506461
# 75%        1.917572
# max        9.432720
# Name: crime_rate, dtype: float64

# %%
np.log(data["crime_rate"] + 1).describe()
# Out:
# count    506.000000
# mean       0.813418
# std        1.022731
# min        0.006300
# 25%        0.078853
# 50%        0.228336
# 75%        1.542674
# max        4.499545
# Name: crime_rate, dtype: float64

# %%
np.exp(data["crime_rate"]).describe()
# Out:
# count    5.060000e+02
# mean     8.664076e+35
# std      1.948935e+37
# min      1.006340e+00
# 25%      1.085505e+00
# 50%      1.292416e+00
# 75%      3.953097e+01
# max      4.384022e+38
# Name: crime_rate, dtype: float64

# %%
data["crime_rate"] = np.log(data["crime_rate"] + 1)

# %%
data["crime_rate"].describe()
# Out:
# count    506.000000
# mean       0.813418
# std        1.022731
# min        0.006300
# 25%        0.078853
# 50%        0.228336
# 75%        1.542674
# max        4.499545
# Name: crime_rate, dtype: float64

# %%
sns.scatterplot(x = data["crime_rate"], y = data["price"])
# Out:
# <AxesSubplot:xlabel='crime_rate', ylabel='price'>

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480     11.19200
# 1   5.12   5.06      22.2       9.14      NO       7.332     12.17280
# 2   5.01   4.97      22.2       4.03      NO       7.394     46.19856
# 3   6.16   5.96      21.3       2.94     YES       9.268     11.26720
# 4   6.37   5.86      21.3       5.33      NO       8.824     11.28960
#
#   waterbody  rainfall     parks
# 0     River        23  0.049347
# 1      Lake        42  0.046146
# 2      None        38  0.045764
# 3      Lake        45  0.047151
# 4      Lake        55  0.039474

# %%
df =pd.get_dummies(data["airport"])

# %%
df.head()
# Out:
#    NO  YES
# 0   0    1
# 1   1    0
# 2   1    0
# 3   0    1
# 4   1    0

# %%
data["airport"] = df["YES"]

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop  airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98        1       5.480     11.19200
# 1   5.12   5.06      22.2       9.14        0       7.332     12.17280
# 2   5.01   4.97      22.2       4.03        0       7.394     46.19856
# 3   6.16   5.96      21.3       2.94        1       9.268     11.26720
# 4   6.37   5.86      21.3       5.33        0       8.824     11.28960
#
#   waterbody  rainfall     parks
# 0     River        23  0.049347
# 1      Lake        42  0.046146
# 2      None        38  0.045764
# 3      Lake        45  0.047151
# 4      Lake        55  0.039474

# %%
data["waterbody"].unique()
# Out:
# array(['River', 'Lake', 'None', 'Lake and River'], dtype=object)

# %%
['None','Lake', 'River', 'Lake and River ']
# Out:
# ['None', 'Lake', 'River', 'Lake and River ']

# %%
from sklearn.preprocessing import OrdinalEncoder

order_mapping= ['None','Lake', 'River', 'Lake and River'][::-1]

encoder = OrdinalEncoder(categories=[order_mapping])

data["waterbody_Encoded"] = encoder.fit_transform(data[["waterbody"]])

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop  airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98        1       5.480     11.19200
# 1   5.12   5.06      22.2       9.14        0       7.332     12.17280
# 2   5.01   4.97      22.2       4.03        0       7.394     46.19856
# 3   6.16   5.96      21.3       2.94        1       9.268     11.26720
# 4   6.37   5.86      21.3       5.33        0       8.824     11.28960
#
#   waterbody  rainfall     parks  waterbody_Encoded
# 0     River        23  0.049347                1.0
# 1      Lake        42  0.046146                2.0
# 2      None        38  0.045764                3.0
# 3      Lake        45  0.047151                2.0
# 4      Lake        55  0.039474                2.0

# %%
del data["waterbody"]

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop  airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98        1       5.480     11.19200
# 1   5.12   5.06      22.2       9.14        0       7.332     12.17280
# 2   5.01   4.97      22.2       4.03        0       7.394     46.19856
# 3   6.16   5.96      21.3       2.94        1       9.268     11.26720
# 4   6.37   5.86      21.3       5.33        0       8.824     11.28960
#
#    rainfall     parks  waterbody_Encoded
# 0        23  0.049347                1.0
# 1        42  0.046146                2.0
# 2        38  0.045764                3.0
# 3        45  0.047151                2.0
# 4        55  0.039474                2.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   price              506 non-null    float64
#  1   crime_rate         506 non-null    float64
#  2   resid_area         506 non-null    float64
#  3   air_qual           506 non-null    float64
#  4   room_num           506 non-null    float64
#  5   age                506 non-null    float64
#  6   dist1              506 non-null    float64
#  7   dist2              506 non-null    float64
#  8   dist3              506 non-null    float64
#  9   dist4              506 non-null    float64
#  10  teachers           506 non-null    float64
#  11  poor_prop          506 non-null    float64
#  12  airport            506 non-null    uint8
#  13  n_hos_beds         506 non-null    float64
#  14  n_hot_rooms        506 non-null    float64
#  15  rainfall           506 non-null    int64
#  16  parks              506 non-null    float64
#  17  waterbody_Encoded  506 non-null    float64
# dtypes: float64(16), int64(1), uint8(1)
# memory usage: 67.8 KB

# %%
data.corr()
# Out:
#                       price  crime_rate  resid_area  air_qual  room_num  \
# price              1.000000   -0.466527   -0.484754 -0.429300  0.696304
# crime_rate        -0.466527    1.000000    0.660283  0.707587 -0.288784
# resid_area        -0.484754    0.660283    1.000000  0.763651 -0.391676
# air_qual          -0.429300    0.707587    0.763651  1.000000 -0.302188
# room_num           0.696304   -0.288784   -0.391676 -0.302188  1.000000
# age               -0.377999    0.559591    0.644779  0.731470 -0.240265
# dist1              0.251355   -0.587703   -0.706481 -0.768589  0.208464
# dist2              0.249459   -0.586127   -0.707956 -0.769724  0.203981
# dist3              0.246650   -0.587988   -0.707566 -0.769157  0.201907
# dist4              0.248200   -0.580101   -0.705819 -0.764873  0.205397
# teachers           0.505655   -0.390052   -0.383248 -0.188933  0.355501
# poor_prop         -0.740836    0.608970    0.603800  0.590879 -0.613808
# airport            0.182867   -0.134486   -0.115401 -0.073903  0.163774
# n_hos_beds         0.108880   -0.004089    0.005799 -0.049553  0.032009
# n_hot_rooms        0.017007    0.056570   -0.003761  0.007238  0.014583
# rainfall          -0.047200    0.082151    0.055845  0.091956 -0.064718
# parks             -0.391574    0.638951    0.707635  0.915544 -0.282817
# waterbody_Encoded -0.041779    0.055170    0.048992  0.037981 -0.050910
#
#                         age     dist1     dist2     dist3     dist4  teachers  \
# price             -0.377999  0.251355  0.249459  0.246650  0.248200  0.505655
# crime_rate         0.559591 -0.587703 -0.586127 -0.587988 -0.580101 -0.390052
# resid_area         0.644779 -0.706481 -0.707956 -0.707566 -0.705819 -0.383248
# air_qual           0.731470 -0.768589 -0.769724 -0.769157 -0.764873 -0.188933
# room_num          -0.240265  0.208464  0.203981  0.201907  0.205397  0.355501
# age                1.000000 -0.746904 -0.746493 -0.747021 -0.746707 -0.261515
# dist1             -0.746904  1.000000  0.997905  0.997735  0.994073  0.232834
# dist2             -0.746493  0.997905  1.000000  0.998097  0.994003  0.233707
# dist3             -0.747021  0.997735  0.998097  1.000000  0.994126  0.233588
# dist4             -0.746707  0.994073  0.994003  0.994126  1.000000  0.228256
# teachers          -0.261515  0.232834  0.233707  0.233588  0.228256  1.000000
# poor_prop          0.602339 -0.498823 -0.495693 -0.494290 -0.496084 -0.374044
# airport            0.005101  0.025208  0.020056  0.020195  0.020022  0.069437
# n_hos_beds        -0.021012 -0.030365 -0.031071 -0.028315 -0.021534 -0.008056
# n_hot_rooms        0.013918 -0.025398 -0.021263 -0.019994 -0.016003 -0.037007
# rainfall           0.074684 -0.036812 -0.037990 -0.041475 -0.032596 -0.045928
# parks              0.673850 -0.706319 -0.708237 -0.709346 -0.703508 -0.187004
# waterbody_Encoded  0.083597 -0.018168 -0.018548 -0.020293 -0.028108 -0.057546
#
#                    poor_prop   airport  n_hos_beds  n_hot_rooms  rainfall  \
# price              -0.740836  0.182867    0.108880     0.017007 -0.047200
# crime_rate          0.608970 -0.134486   -0.004089     0.056570  0.082151
# resid_area          0.603800 -0.115401    0.005799    -0.003761  0.055845
# air_qual            0.590879 -0.073903   -0.049553     0.007238  0.091956
# room_num           -0.613808  0.163774    0.032009     0.014583 -0.064718
# age                 0.602339  0.005101   -0.021012     0.013918  0.074684
# dist1              -0.498823  0.025208   -0.030365    -0.025398 -0.036812
# dist2              -0.495693  0.020056   -0.031071    -0.021263 -0.037990
# dist3              -0.494290  0.020195   -0.028315    -0.019994 -0.041475
# dist4              -0.496084  0.020022   -0.021534    -0.016003 -0.032596
# teachers           -0.374044  0.069437   -0.008056    -0.037007 -0.045928
# poor_prop           1.000000 -0.095054   -0.066008     0.017036  0.061444
# airport            -0.095054  1.000000   -0.006365    -0.055338 -0.013171
# n_hos_beds         -0.066008 -0.006365    1.000000    -0.003130  0.058596
# n_hot_rooms         0.017036 -0.055338   -0.003130     1.000000  0.014869
# rainfall            0.061444 -0.013171    0.058596     0.014869  1.000000
# parks               0.552310 -0.052503   -0.071272     0.023757  0.078278
# waterbody_Encoded   0.077613  0.040373   -0.006971     0.029616 -0.068029
#
#                       parks  waterbody_Encoded
# price             -0.391574          -0.041779
# crime_rate         0.638951           0.055170
# resid_area         0.707635           0.048992
# air_qual           0.915544           0.037981
# room_num          -0.282817          -0.050910
# age                0.673850           0.083597
# dist1             -0.706319          -0.018168
# dist2             -0.708237          -0.018548
# dist3             -0.709346          -0.020293
# dist4             -0.703508          -0.028108
# teachers          -0.187004          -0.057546
# poor_prop          0.552310           0.077613
# airport           -0.052503           0.040373
# n_hos_beds        -0.071272          -0.006971
# n_hot_rooms        0.023757           0.029616
# rainfall           0.078278          -0.068029
# parks              1.000000           0.044396
# waterbody_Encoded  0.044396           1.000000

# %% [markdown]
# # Important Features:
#
# - poor_prop
# - room_num
# - teachers
# - resid_area
# - crime_rate

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (13, 13))

sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', center=0, square=True)
# Out:
# <AxesSubplot:>

# %%
data[["dist1", "dist2","dist3", "dist4"]].describe()
# Out:
#             dist1       dist2       dist3       dist4
# count  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972
# std      2.108532    2.108580    2.119797    2.099203
# min      1.130000    0.920000    1.150000    0.730000
# 25%      2.270000    1.940000    2.232500    1.940000
# 50%      3.385000    3.010000    3.375000    3.070000
# 75%      5.367500    4.992500    5.407500    4.985000
# max     12.320000   11.930000   12.320000   11.940000

# %%
data["avg_dist"] = (data["dist1"]+data["dist2"]+data["dist3"]+data["dist4"])/4

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop  airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98        1       5.480     11.19200
# 1   5.12   5.06      22.2       9.14        0       7.332     12.17280
# 2   5.01   4.97      22.2       4.03        0       7.394     46.19856
# 3   6.16   5.96      21.3       2.94        1       9.268     11.26720
# 4   6.37   5.86      21.3       5.33        0       8.824     11.28960
#
#    rainfall     parks  waterbody_Encoded  avg_dist
# 0        23  0.049347                1.0    4.0875
# 1        42  0.046146                2.0    4.9675
# 2        38  0.045764                3.0    4.9675
# 3        45  0.047151                2.0    6.0650
# 4        55  0.039474                2.0    6.0625

# %%
data.drop(["dist1", "dist2","dist3", "dist4"], axis=1,inplace=True)

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  airport  n_hos_beds  n_hot_rooms  rainfall     parks  \
# 0       4.98        1       5.480     11.19200        23  0.049347
# 1       9.14        0       7.332     12.17280        42  0.046146
# 2       4.03        0       7.394     46.19856        38  0.045764
# 3       2.94        1       9.268     11.26720        45  0.047151
# 4       5.33        0       8.824     11.28960        55  0.039474
#
#    waterbody_Encoded  avg_dist
# 0                1.0    4.0875
# 1                2.0    4.9675
# 2                3.0    4.9675
# 3                2.0    6.0650
# 4                2.0    6.0625

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (13, 13))

sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', center=0, square=True)
# Out:
# <AxesSubplot:>

# %%
data[["parks", "air_qual"]].describe()
# Out:
#             parks    air_qual
# count  506.000000  506.000000
# mean     0.054454    0.554695
# std      0.010632    0.115878
# min      0.033292    0.385000
# 25%      0.046464    0.449000
# 50%      0.053507    0.538000
# 75%      0.061397    0.624000
# max      0.086711    0.871000

# %%
del data["parks"]

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  airport  n_hos_beds  n_hot_rooms  rainfall  waterbody_Encoded  \
# 0       4.98        1       5.480     11.19200        23                1.0
# 1       9.14        0       7.332     12.17280        42                2.0
# 2       4.03        0       7.394     46.19856        38                3.0
# 3       2.94        1       9.268     11.26720        45                2.0
# 4       5.33        0       8.824     11.28960        55                2.0
#
#    avg_dist
# 0    4.0875
# 1    4.9675
# 2    4.9675
# 3    6.0650
# 4    6.0625

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (13, 13))

sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', center=0, square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model Selection Process

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# $$Y = mx +c $$

# %% [markdown]
# **unvariant analysis**
#
# $$y = wx + b$$
#
# **miltiple LR**
# $$y =b + w1x1 + w2x2 + w3x3 +w4x4 .... wnxn$$

# %%
sns.regplot(x = data["poor_prop"], y = data["price"])
# Out:
# <AxesSubplot:xlabel='poor_prop', ylabel='price'>

# %%
y = data["price"]
x = data.drop("price",axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model.intercept_, model.coef_
# Out:
# (-7.051987076411745,
#  array([ 1.86498063e-02, -4.15082527e-02, -1.60534044e+01,  4.00355447e+00,
#         -5.28860590e-03,  1.01592650e+00, -5.77863233e-01,  1.14774928e+00,
#          3.30798900e-01,  9.31430685e-02,  1.56388239e-02,  2.21234479e-01,
#         -1.21772874e+00]))

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  airport  n_hos_beds  n_hot_rooms  rainfall  waterbody_Encoded  \
# 0       4.98        1       5.480     11.19200        23                1.0
# 1       9.14        0       7.332     12.17280        42                2.0
# 2       4.03        0       7.394     46.19856        38                3.0
# 3       2.94        1       9.268     11.26720        45                2.0
# 4       5.33        0       8.824     11.28960        55                2.0
#
#    avg_dist
# 0    4.0875
# 1    4.9675
# 2    4.9675
# 3    6.0650
# 4    6.0625

# %%
y_pred = model.predict(x_train)
y_pred_sel = model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_train, y_pred)
# Out:
# 0.7280787213703903

# %%
r2_score(y_test, y_pred_sel)
# Out:
# 0.6794324224036175

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(max_depth=3, random_state=42)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=3, random_state=42)

# %%
y_pred = rf.predict(x_train)

# %%
y_pred_sel = rf.predict(x_test)

# %%
r2_score(y_train, y_pred)
# Out:
# 0.8728953516383917

# %%
r2_score(y_test, y_pred_sel)
# Out:
# 0.8183867780218319

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.datasets import make_regression

# %%
reg = DecisionTreeRegressor(criterion = 'mse', max_depth = 3, random_state = 42)

# %%
reg.fit(x_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# DecisionTreeRegressor(criterion='mse', max_depth=3, random_state=42)

# %%
reg.score(x_train, y_train)
# Out:
# 0.8312339079747152

# %%
reg.score(x_test, y_test)
# Out:
# 0.8189516802449259

# %% [markdown]
# ### Evaluation of the Model Selection Process

# %% [markdown]
# - The linear regression, random forest and decision tree processes were carried out on the model and the decision tree was found to have the best performance

# %% [markdown]
# # Parameter Tuning and Training the Final Model

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  airport  n_hos_beds  n_hot_rooms  rainfall  waterbody_Encoded  \
# 0       4.98        1       5.480     11.19200        23                1.0
# 1       9.14        0       7.332     12.17280        42                2.0
# 2       4.03        0       7.394     46.19856        38                3.0
# 3       2.94        1       9.268     11.26720        45                2.0
# 4       5.33        0       8.824     11.28960        55                2.0
#
#    avg_dist
# 0    4.0875
# 1    4.9675
# 2    4.9675
# 3    6.0650
# 4    6.0625

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

# %%
param_grid = {
    'criterion': ['mse', 'friedman_mse', 'mae'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
grid_search = GridSearchCV(estimator=reg, param_grid=param_grid, scoring='neg_mean_squared_error', cv=2, verbose=2, n_jobs=-1)

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 2 folds for each of 216 candidates, totalling 432 fits
# GridSearchCV(cv=2,
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=3,
#                                              random_state=42),
#              n_jobs=-1,
#              param_grid={'criterion': ['mse', 'friedman_mse', 'mae'],
#                          'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error', verbose=2)

# %%
best_params = grid_search.best_params_
best_reg_model = grid_search.best_estimator_

# %%
# Evaluating the best model on the train data
accuracy = best_reg_model.score(x_train, y_train)
print("Best Hyperparameters:", best_params)
print("Accuracy:", accuracy)
# Out:
# Best Hyperparameters: {'criterion': 'mae', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'random'}
# Accuracy: 0.9374683956283674

# %%
# Evaluating the best model on the test data
accuracy = best_reg_model.score(x_test, y_test)
print("Best Hyperparameters:", best_params)
print("Accuracy:", accuracy)
# Out:
# Best Hyperparameters: {'criterion': 'mae', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'random'}
# Accuracy: 0.8144302251790321

# %% [markdown]
# # Saving the Model

# %%
import pickle

# %%
filename = 'house_price.pkl'
pickle.dump(best_reg_model,open(filename,'wb'))

# %% [markdown]
# # Loading the Model

# %%
import pickle

# %%
filename = 'house_price.pkl'

# %%
loaded_model = pickle.load(open(filename,'rb'))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
house_data = {
 'price': 21.6,
 'crime_rate': 0.02731,
 'resid_area': 37.07,
 'air_qual': 0.469,
 'room_num': 6.421,
 'age': 78.9,
 'dist1': 4.99,
 'dist2': 4.7,
 'dist3': 5.12,
 'dist4': 5.06,
 'teachers': 22.2,
 'poor_prop': 9.14,
 'airport': 'NO',
 'n_hos_beds': 7.332,
 'n_hot_rooms': 12.1728,
 'waterbody': 'Lake',
 'rainfall': 42,
 'bus_ter': 'YES',
 'parks': 0.046145633
 }
